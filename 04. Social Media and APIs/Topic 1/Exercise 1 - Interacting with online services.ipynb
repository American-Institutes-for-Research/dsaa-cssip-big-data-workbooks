# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append("../modules/orcid-python")
sys.path.append("../modules/pyalm")
import requests
import time
import orcid
import pyalm.pyalm as pyalm
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ##Part A Getting online (X points)##
#
# The first part of the exercise is to simply to successfully request a page online and recieve back a 200 HTTP response. We imported the requests library above and will download the google.com page. This exercise is largely to ensure that you have a properly functioning internet connection!
#
# <div class="alert alert-success">
# An example of using the `requests` library is shown in the first notebook from the book chapter. Adapt that code to download the homepage of google.com and show that the HTTP status response code is 200.
# </div>
#
# NOTE FOR EHMAD/CHRISTINA: I'm going to start with all the code in there and then take some it out. That at least proves that it works!

# %%
# First give the URL that you want to obtain
url = 'http://google.com'

# Then set up the request. Look at example Notebook #1 for this session and copy the names of object that the
# request response will go into.
response = requests.get(url)

# %%
assert response.status_code == 200 # If you get the code above working this assertion should pass

# %% [markdown]
# ##Part B Obtaining metadata from Crossref (X points)##
#
# Now we have a working connection we will obtain some bibliographic metadata from Crossref. In the example notebook we obtained data from a single DOI. First we will replicate that for a different DOI
#
# <div class="alert alert-success">
# Obtain the Crossref metadata for the DOI 10.1038/171740a0 Obtain the names of the authors of this article and its title.
# </div>

# %%
DOI = '10.1038/171740a0'
query = 'works/'
urlbase = 'http://api.crossref.org/'

# Now write the code the obtain the relevant JSON metadata, check that the status code is 200.
# In a second cell below uncomment the code to look at the JSON output, then select the author's surnames to print

url = urlbase+query+DOI
response = requests.get(url)
assert response.status_code == 200

# %%
j = response.json()
j
# Out:
# {u'message': {u'DOI': u'10.1038/171740a0',
#   u'ISSN': [u'0028-0836'],
#   u'URL': u'http://dx.doi.org/10.1038/171740a0',
#   u'alternative-id': [u'171740a0'],
#   u'author': [{u'affiliation': [],
#     u'family': u'FRANKLIN',
#     u'given': u'ROSALIND E.'},
#    {u'affiliation': [], u'family': u'GOSLING', u'given': u'R. G.'}],
#   u'container-title': [u'Nature'],
#   u'deposited': {u'date-parts': [[2011, 8, 22]], u'timestamp': 1313971200000},
#   u'indexed': {u'date-parts': [[2015, 6, 7]], u'timestamp': 1433643716355},
#   u'issue': u'4356',
#   u'issued': {u'date-parts': [[1953, 4, 25]]},
#   u'member': u'http://id.crossref.org/member/339',
#   u'page': u'740-741',
#   u'prefix': u'http://id.crossref.org/prefix/10.1038',
#   u'publisher': u'Nature Publishing Group',
#   u'reference-count': 8,
#   u'score': 1.0,
#   u'source': u'CrossRef',
#   u'subject': [u'General'],
#   u'subtitle': [],
#   u'title': [u'Molecular Configuration in Sodium Thymonucleate'],
#   u'type': u'journal-article',
#   u'volume': u'171'},
#  u'message-type': u'work',
#  u'message-version': u'1.0.0',
#  u'status': u'ok'}

# %%
# Now use your knowledge of python dictionaries to print the surname of each of the authors
surname1 = j['message']['author'][0]['family']
surname2 = j['message']['author'][1]['family']
print surname1, '\n', surname2
# Out:
# FRANKLIN
# GOSLING

# %% [markdown]
# NOTE FOR EHMAD/CHRISTINA - The authors surnames are Franklin and Gosling (possibly in capitals). This is the Rosalind Franklin article that provided the evidence backing up Watson and Crick's paper on the structure of DNA. Not sure how to set up the marking for this but they should be able to pull out the surnames by inspecting the JSON.

# %% [markdown]
# ##PART C - Obtaining a list of DOIs##
#
# In this part of the exercise you will do something not covered in the class notes, obtain a set of DOIs from the Crossref search API. In the notes we show collecting DOIs from ORCID. In the second set of exercises we will show an example using a publisher API.
#
# To prepare for this you will need to look at the API documentation at https://github.com/CrossRef/rest-api-doc/blob/master/rest_api.md. In particular look at the section on queries. You will see that quite sophisticated queries are possible. You may want to test some examples and look at the results below. Think carefully about how you want to construct the URL for your query as you do this.
#
# NOTE: Not too sure what to test here, just make sure they get back enough results? Probably the top ones should stay the top depending on the query but more an exercise in getting them playing with the parameters than anything else.

# %%
url = 'http://api.crossref.org/works?query=Martin+Karplus'
response = requests.get(url)
j = response.json()
j
# Out:
# {u'message': {u'facets': {},
#   u'items': [{u'DOI': u'10.1002/9780470034590.emrhp0093',
#     u'ISBN': [u'http://id.crossref.org/isbn/0470034599',
#      u'http://id.crossref.org/isbn/9780470034590'],
#     u'URL': u'http://dx.doi.org/10.1002/9780470034590.emrhp0093',
#     u'author': [{u'affiliation': [],
#       u'family': u'Karplus',
#       u'given': u'Martin'}],
#     u'container-title': [u'Encyclopedia of Magnetic Resonance'],
#     u'deposited': {u'date-parts': [[2009, 10, 31]],
#      u'timestamp': 1256947200000},
#     u'indexed': {u'date-parts': [[2015, 6, 10]], u'timestamp': 1433952987397},
#     u'issued': {u'date-parts': [[2007, 3, 15]]},
#     u'member': u'http://id.crossref.org/member/311',
#     u'prefix': u'http://id.crossref.org/prefix/10.1002',
#     u'publisher': u'Wiley-Blackwell',
#     u'reference-count': 28,
#     u'score': 4.548803,
#     u'source': u'CrossRef',
#     u'subtitle': [],
#     u'title': [u'Karplus, Martin: Theory of Vicinal Coupling Constants'],
#     u'type': u'reference-entry'},
#    {u'DOI': u'10.1063/1.881116',
#     u'ISSN': [u'0031-9228'],
#     u'URL': u'http://dx.doi.org/10.1063/1.881116',
#     u'author': [{u'affiliation': [],
#       u'family': u'Karplus',
#       u'given': u'Martin'}],
#     u'container-title': [u'Phys. Today', u'Physics Today'],
#     u'deposited': {u'date-parts': [[2014, 3, 1]], u'timestamp': 1393632000000},
#     u'indexed': {u'date-parts': [[2015, 6, 9]], u'timestamp': 1433873139706},
#     u'issue': u'10',
#     u'issued': {u'date-parts': [[1987]]},
#     u'member': u'http://id.crossref.org/member/317',
#     u'page': u'68',
#     u'prefix': u'http://id.crossref.org/prefix/10.1063',
#     u'publisher': u'AIP Publishing',
#     u'reference-count': 8,
#     u'score': 3.2164893,
#     u'source': u'CrossRef',
#     u'subject': [u'Physics and Astronomy(all)'],
#     u'subtitle': [],
#     u'title': [u'Molecular Dynamics Simulations of Proteins'],
#     u'type': u'journal-article',
#     u'volume': u'40'},
#    {u'DOI': u'10.1038/260404a0',
#     u'ISSN': [u'0028-0836'],
#     u'URL': u'http://dx.doi.org/10.1038/260404a0',
#     u'alternative-id': [u'260404a0'],
#     u'author': [{u'affiliation': [],
#       u'family': u'Karplus',
#       u'given': u'Martin'},
#      {u'affiliation': [], u'family': u'Weaver', u'given': u'David L.'}],
#     u'container-title': [u'Nature'],
#     u'deposited': {u'date-parts': [[2011, 7, 24]],
#      u'timestamp': 1311465600000},
#     u'indexed': {u'date-parts': [[2015, 6, 6]], u'timestamp': 1433601658697},
#     u'issue': u'5550',
#     u'issued': {u'date-parts': [[1976, 4, 1]]},
#     u'member': u'http://id.crossref.org/member/339',
#     u'page': u'404-406',
#     u'prefix': u'http://id.crossref.org/prefix/10.1038',
#     u'publisher': u'Nature Publishing Group',
#     u'reference-count': 36,
#     u'score': 3.2164893,
#     u'source': u'CrossRef',
#     u'subject': [u'General'],
#     u'subtitle': [],
#     u'title': [u'Protein-folding dynamics'],
#     u'type': u'journal-article',
#     u'volume': u'260'},
#    {u'DOI': u'10.2172/805789',
#     u'URL': u'http://dx.doi.org/10.2172/805789',
#     u'author': [{u'affiliation': [],
#       u'family': u'Karplus',
#       u'given': u'Martin'}],
#     u'container-title': [],
#     u'deposited': {u'date-parts': [[2013, 12, 16]],
#      u'timestamp': 1387152000000},
#     u'indexed': {u'date-parts': [[2015, 6, 3]], u'timestamp': 1433344930882},
#     u'issued': {u'date-parts': [[2001, 9, 3]]},
#     u'member': u'http://id.crossref.org/member/960',
#     u'prefix': u'http://id.crossref.org/prefix/10.2172',
#     u'publisher': u'Office of Scientific and Technical Information (OSTI)',
#     u'reference-count': 0,
#     u'score': 3.2164893,
#     u'source': u'CrossRef',
#     u'subtitle': [],
#     u'title': [u'Final progress report for DOE grant [Protein dynamics and biocatalysis]'],
#     u'type': u'report'},
#    {u'DOI': u'10.1007/978-1-4684-5745-2_17',
#     u'ISBN': [u'http://id.crossref.org/isbn/978-1-4684-5747-6',
#      u'http://id.crossref.org/isbn/978-1-4684-5745-2'],
#     u'URL': u'http://dx.doi.org/10.1007/978-1-4684-5745-2_17',
#     u'author': [{u'affiliation': [],
#       u'family': u'Karplus',
#       u'given': u'Martin'}],
#     u'container-title': [u'Protein Structure and Engineering'],
#     u'deposited': {u'date-parts': [[2013, 5, 21]],
#      u'timestamp': 1369094400000},
#     u'indexed': {u'date-parts': [[2015, 6, 11]], u'timestamp': 1434007036346},
#     u'issued': {u'date-parts': [[1989]]},
#     u'member': u'http://id.crossref.org/member/297',
#     u'page': u'269-290',
#     u'prefix': u'http://id.crossref.org/prefix/10.1007',
#     u'publisher': u'Springer Science + Business Media',
#     u'reference-count': 0,
#     u'score': 3.2164893,
#     u'source': u'CrossRef',
#     u'subtitle': [],
#     u'title': [u'Molecular Dynamics: Applications to Proteins'],
#     u'type': u'book-chapter'},
#    {u'DOI': u'10.1007/978-1-4684-4220-5_15',
#     u'ISBN': [u'http://id.crossref.org/isbn/978-1-4684-4222-9',
#      u'http://id.crossref.org/isbn/978-1-4684-4220-5'],
#     u'URL': u'http://dx.doi.org/10.1007/978-1-4684-4220-5_15',
#     u'author': [{u'affiliation': [],
#       u'family': u'Karplus',
#       u'given': u'Martin'}],
#     u'container-title': [u'Structural Molecular Biology'],
#     u'deposited': {u'date-parts': [[2014, 1, 10]],
#      u'timestamp': 1389312000000},
#     u'indexed': {u'date-parts': [[2015, 6, 12]], u'timestamp': 1434077283362},
#     u'issued': {u'date-parts': [[1982]]},
#     u'member': u'http://id.crossref.org/member/297',
#     u'page': u'427-453',
#     u'prefix': u'http://id.crossref.org/prefix/10.1007',
#     u'publisher': u'Springer Science + Business Media',
#     u'reference-count': 0,
#     u'score': 3.2164893,
#     u'source': u'CrossRef',
#     u'subtitle': [],
#     u'title': [u'Dynamics of Peptides and Proteins'],
#     u'type': u'book-chapter'},
#    {u'DOI': u'10.1007/978-1-4684-5547-2_7',
#     u'ISBN': [u'http://id.crossref.org/isbn/978-1-4684-5549-6',
#      u'http://id.crossref.org/isbn/978-1-4684-5547-2'],
#     u'URL': u'http://dx.doi.org/10.1007/978-1-4684-5547-2_7',
#     u'author': [{u'affiliation': [],
#       u'family': u'Karplus',
#       u'given': u'Martin'}],
#     u'container-title': [u'Biotechnology and the Human Genome'],
#     u'deposited': {u'date-parts': [[2014, 1, 10]],
#      u'timestamp': 1389312000000},
#     u'indexed': {u'date-parts': [[2015, 6, 12]], u'timestamp': 1434077522782},
#     u'issued': {u'date-parts': [[1988]]},
#     u'member': u'http://id.crossref.org/member/297',
#     u'page': u'57-61',
#     u'prefix': u'http://id.crossref.org/prefix/10.1007',
#     u'publisher': u'Springer Science + Business Media',
#     u'reference-count': 0,
#     u'score': 3.2164893,
#     u'source': u'CrossRef',
#     u'subtitle': [],
#     u'title': [u'Proteins: Dynamics and Function'],
#     u'type': u'book-chapter'},
#    {u'DOI': u'10.1007/978-94-010-2156-2_8',
#     u'ISBN': [u'http://id.crossref.org/isbn/978-94-010-2158-6',
#      u'http://id.crossref.org/isbn/978-94-010-2156-2'],
#     u'URL': u'http://dx.doi.org/10.1007/978-94-010-2156-2_8',
#     u'author': [{u'affiliation': [],
#       u'family': u'Karplus',
#       u'given': u'Martin'}],
#     u'container-title': [u'The World of Quantum Chemistry'],
#     u'deposited': {u'date-parts': [[2011, 9, 29]],
#      u'timestamp': 1317254400000},
#     u'indexed': {u'date-parts': [[2015, 6, 10]], u'timestamp': 1433968627984},
#     u'issued': {u'date-parts': [[1974]]},
#     u'member': u'http://id.crossref.org/member/297',
#     u'page': u'101-111',
#     u'prefix': u'http://id.crossref.org/prefix/10.1007',
#     u'publisher': u'Springer Science + Business Media',
#     u'reference-count': 0,
#     u'score': 3.2164893,
#     u'source': u'CrossRef',
#     u'subtitle': [],
#     u'title': [u'Quantum Mechanics of Simple Chemical Reactions'],
#     u'type': u'book-chapter'},
#    {u'DOI': u'10.1007/978-94-009-7052-6_19',
#     u'ISBN': [u'http://id.crossref.org/isbn/978-94-009-7054-0',
#      u'http://id.crossref.org/isbn/978-94-009-7052-6'],
#     u'URL': u'http://dx.doi.org/10.1007/978-94-009-7052-6_19',
#     u'author': [{u'affiliation': [],
#       u'family': u'Karplus',
#       u'given': u'Martin'}],
#     u'container-title': [u'Structure, Dynamics, Interactions and Evolution of Biological Macromolecules'],
#     u'deposited': {u'date-parts': [[2011, 10, 10]],
#      u'timestamp': 1318204800000},
#     u'indexed': {u'date-parts': [[2015, 6, 10]], u'timestamp': 1433969146078},
#     u'issued': {u'date-parts': [[1983]]},
#     u'member': u'http://id.crossref.org/member/297',
#     u'page': u'253-269',
#     u'prefix': u'http://id.crossref.org/prefix/10.1007',
#     u'publisher': u'Springer Science + Business Media',
#     u'reference-count': 0,
#     u'score': 3.2164893,
#     u'source': u'CrossRef',
#     u'subtitle': [],
#     u'title': [u'Dynamics of Proteins'],
#     u'type': u'book-chapter'},
#    {u'DOI': u'10.1038/43940',
#     u'ISSN': [u'0028-0836'],
#     u'URL': u'http://dx.doi.org/10.1038/43940',
#     u'alternative-id': [u'43940'],
#     u'author': [{u'affiliation': [], u'family': u'Zhou', u'given': u'Yaoqi'},
#      {u'affiliation': [], u'family': u'Karplus', u'given': u'Martin'}],
#     u'container-title': [u'Nature'],
#     u'deposited': {u'date-parts': [[2011, 5, 10]],
#      u'timestamp': 1304985600000},
#     u'indexed': {u'date-parts': [[2015, 9, 6]], u'timestamp': 1441517686178},
#     u'issue': u'6751',
#     u'issued': {u'date-parts': [[1999, 9, 23]]},
#     u'member': u'http://id.crossref.org/member/339',
#     u'page': u'400-403',
#     u'prefix': u'http://id.crossref.org/prefix/10.1038',
#     u'publisher': u'Nature Publishing Group',
#     u'reference-count': 0,
#     u'score': 3.2164893,
#     u'source': u'CrossRef',
#     u'subject': [u'General'],
#     u'subtitle': [],
#     u'title': [],
#     u'type': u'journal-article',
#     u'volume': u'401'},
#    {u'DOI': u'10.1038/35099587',
#     u'ISSN': [u'0028-0836'],
#     u'URL': u'http://dx.doi.org/10.1038/35099587',
#     u'alternative-id': [u'35099587'],
#     u'author': [{u'affiliation': [],
#       u'family': u'Dinner',
#       u'given': u'Aaron R.'},
#      {u'affiliation': [], u'family': u'Blackburn', u'given': u'G. Michael'},
#      {u'affiliation': [], u'family': u'Karplus', u'given': u'Martin'}],
#     u'container-title': [u'Nature'],
#     u'deposited': {u'date-parts': [[2011, 7, 15]],
#      u'timestamp': 1310688000000},
#     u'indexed': {u'date-parts': [[2015, 9, 6]], u'timestamp': 1441517687142},
#     u'issue': u'6857',
#     u'issued': {u'date-parts': [[2001, 10, 18]]},
#     u'member': u'http://id.crossref.org/member/339',
#     u'page': u'752-755',
#     u'prefix': u'http://id.crossref.org/prefix/10.1038',
#     u'publisher': u'Nature Publishing Group',
#     u'reference-count': 0,
#     u'score': 3.2164893,
#     u'source': u'CrossRef',
#     u'subject': [u'General'],
#     u'subtitle': [],
#     u'title': [],
#     u'type': u'journal-article',
#     u'volume': u'413'},
#    {u'DOI': u'10.1110/ps.03259908',
#     u'ISSN': [u'0961-8368', u'1469-896X'],
#     u'URL': u'http://dx.doi.org/10.1110/ps.03259908',
#     u'author': [{u'affiliation': [], u'family': u'Cui', u'given': u'Qiang'},
#      {u'affiliation': [], u'family': u'Karplus', u'given': u'Martin'}],
#     u'container-title': [u'Protein Sci.', u'Protein Science'],
#     u'deposited': {u'date-parts': [[2011, 8, 14]],
#      u'timestamp': 1313280000000},
#     u'indexed': {u'date-parts': [[2015, 6, 6]], u'timestamp': 1433628301530},
#     u'issue': u'8',
#     u'issued': {u'date-parts': [[2008, 8]]},
#     u'member': u'http://id.crossref.org/member/311',
#     u'page': u'1295-1307',
#     u'prefix': u'http://id.crossref.org/prefix/10.1002',
#     u'publisher': u'Wiley-Blackwell',
#     u'reference-count': 107,
#     u'score': 2.8144283,
#     u'source': u'CrossRef',
#     u'subject': [u'Molecular Biology', u'Biochemistry'],
#     u'subtitle': [],
#     u'title': [u'Allostery and cooperativity revisited'],
#     u'type': u'journal-article',
#     u'volume': u'17'},
#    {u'DOI': u'10.1038/267585a0',
#     u'ISSN': [u'0028-0836'],
#     u'URL': u'http://dx.doi.org/10.1038/267585a0',
#     u'alternative-id': [u'267585a0'],
#     u'author': [{u'affiliation': [],
#       u'family': u'McCammon',
#       u'given': u'J. Andrew'},
#      {u'affiliation': [], u'family': u'Gelin', u'given': u'Bruce R.'},
#      {u'affiliation': [], u'family': u'Karplus', u'given': u'Martin'}],
#     u'container-title': [u'Nature'],
#     u'deposited': {u'date-parts': [[2011, 8, 15]],
#      u'timestamp': 1313366400000},
#     u'indexed': {u'date-parts': [[2015, 6, 7]], u'timestamp': 1433636308732},
#     u'issue': u'5612',
#     u'issued': {u'date-parts': [[1977, 6, 16]]},
#     u'member': u'http://id.crossref.org/member/339',
#     u'page': u'585-590',
#     u'prefix': u'http://id.crossref.org/prefix/10.1038',
#     u'publisher': u'Nature Publishing Group',
#     u'reference-count': 40,
#     u'score': 2.8144283,
#     u'source': u'CrossRef',
#     u'subject': [u'General'],
#     u'subtitle': [],
#     u'title': [u'Dynamics of folded proteins'],
#     u'type': u'journal-article',
#     u'volume': u'267'},
#    {u'DOI': u'10.1002/bip.1979.360180608',
#     u'ISSN': [u'0006-3525', u'1097-0282'],
#     u'URL': u'http://dx.doi.org/10.1002/bip.1979.360180608',
#     u'author': [{u'affiliation': [],
#       u'family': u'Karplus',
#       u'given': u'Martin'},
#      {u'affiliation': [], u'family': u'Weaver', u'given': u'David L.'}],
#     u'container-title': [u'Biopolymers'],
#     u'deposited': {u'date-parts': [[2011, 6, 11]],
#      u'timestamp': 1307750400000},
#     u'indexed': {u'date-parts': [[2015, 6, 6]], u'timestamp': 1433609268366},
#     u'issue': u'6',
#     u'issued': {u'date-parts': [[1979, 6]]},
#     u'member': u'http://id.crossref.org/member/311',
#     u'page': u'1421-1437',
#     u'prefix': u'http://id.crossref.org/prefix/10.1002',
#     u'publisher': u'Wiley-Blackwell',
#     u'reference-count': 27,
#     u'score': 2.8144283,
#     u'source': u'CrossRef',
#     u'subject': [u'Organic Chemistry',
#      u'Biomaterials',
#      u'Biochemistry',
#      u'Biophysics'],
#     u'subtitle': [],
#     u'title': [u'Diffusion-collision model for protein folding'],
#     u'type': u'journal-article',
#     u'volume': u'18'},
#    {u'DOI': u'10.1063/1.2811490',
#     u'ISSN': [u'0031-9228'],
#     u'URL': u'http://dx.doi.org/10.1063/1.2811490',
#     u'author': [{u'affiliation': [],
#       u'family': u'Mulkern',
#       u'given': u'Robert V.'},
#      {u'affiliation': [], u'family': u'Karplus', u'given': u'Martin'}],
#     u'container-title': [u'Phys. Today', u'Physics Today'],
#     u'deposited': {u'date-parts': [[2014, 3, 1]], u'timestamp': 1393632000000},
#     u'indexed': {u'date-parts': [[2015, 6, 9]], u'timestamp': 1433873075990},
#     u'issue': u'7',
#     u'issued': {u'date-parts': [[1988]]},
#     u'member': u'http://id.crossref.org/member/317',
#     u'page': u'15',
#     u'prefix': u'http://id.crossref.org/prefix/10.1063',
#     u'publisher': u'AIP Publishing',
#     u'reference-count': 0,
#     u'score': 2.8144283,
#     u'source': u'CrossRef',
#     u'subject': [u'Physics and Astronomy(all)'],
#     u'subtitle': [],
#     u'title': [u'The Long and Short of Relaxation Times'],
#     u'type': u'journal-article',
#     u'volume': u'41'},
#    {u'DOI': u'10.1016/s1359-0278(97)00067-9',
#     u'ISSN': [u'1359-0278'],
#     u'URL': u'http://dx.doi.org/10.1016/s1359-0278(97)00067-9',
#     u'alternative-id': [u'S1359027897000679'],
#     u'author': [{u'affiliation': [],
#       u'family': u'Karplus',
#       u'given': u'Martin'}],
#     u'container-title': [u'Folding and Design'],
#     u'deposited': {u'date-parts': [[2015, 4, 14]],
#      u'timestamp': 1428969600000},
#     u'indexed': {u'date-parts': [[2015, 6, 10]], u'timestamp': 1433903732288},
#     u'issued': {u'date-parts': [[1997, 6]]},
#     u'license': [{u'URL': u'http://www.elsevier.com/tdm/userlicense/1.0/',
#       u'content-version': u'tdm',
#       u'delay-in-days': 0,
#       u'start': {u'date-parts': [[1997, 6, 1]], u'timestamp': 865123200000}},
#      {u'URL': u'http://www.elsevier.com/open-access/userlicense/1.0/',
#       u'content-version': u'vor',
#       u'delay-in-days': 5892,
#       u'start': {u'date-parts': [[2013, 7, 19]],
#        u'timestamp': 1374192000000}}],
#     u'link': [{u'URL': u'http://api.elsevier.com/content/article/PII:S1359027897000679?httpAccept=text/xml',
#       u'content-type': u'text/xml',
#       u'content-version': u'vor',
#       u'intended-application': u'text-mining'},
#      {u'URL': u'http://api.elsevier.com/content/article/PII:S1359027897000679?httpAccept=text/plain',
#       u'content-type': u'text/plain',
#       u'content-version': u'vor',
#       u'intended-application': u'text-mining'}],
#     u'member': u'http://id.crossref.org/member/78',
#     u'page': u'S69-S75',
#     u'prefix': u'http://id.crossref.org/prefix/10.1016',
#     u'publisher': u'Elsevier BV',
#     u'reference-count': 75,
#     u'score': 2.8144283,
#     u'source': u'CrossRef',
#     u'subject': [u'Molecular Medicine', u'Biochemistry'],
#     u'subtitle': [],
#     u'title': [u'The Levinthal paradox: yesterday and today'],
#     u'type': u'journal-article',
#     u'volume': u'2'},
#    {u'DOI': u'10.1038/nchembio.565',
#     u'ISSN': [u'1552-4450', u'1552-4469'],
#     u'URL': u'http://dx.doi.org/10.1038/nchembio.565',
#     u'alternative-id': [u'nchembio.565'],
#     u'author': [{u'affiliation': [],
#       u'family': u'Karplus',
#       u'given': u'Martin'}],
#     u'container-title': [u'Nature Chemical Biology', u'Nat Chem Biol'],
#     u'deposited': {u'date-parts': [[2011, 8, 17]],
#      u'timestamp': 1313539200000},
#     u'indexed': {u'date-parts': [[2015, 6, 7]], u'timestamp': 1433684083426},
#     u'issue': u'7',
#     u'issued': {u'date-parts': [[2011, 6, 17]]},
#     u'member': u'http://id.crossref.org/member/339',
#     u'page': u'401-404',
#     u'prefix': u'http://id.crossref.org/prefix/10.1038',
#     u'publisher': u'Nature Publishing Group',
#     u'reference-count': 25,
#     u'score': 2.8144283,
#     u'source': u'CrossRef',
#     u'subject': [u'Molecular Biology', u'Cell Biology'],
#     u'subtitle': [],
#     u'title': [u'Behind the folding funnel diagram'],
#     u'type': u'journal-article',
#     u'volume': u'7'},
#    {u'DOI': u'10.1038/nchembio0911-648d',
#     u'ISSN': [u'1552-4450', u'1552-4469'],
#     u'URL': u'http://dx.doi.org/10.1038/nchembio0911-648d',
#     u'alternative-id': [u'nchembio0911-648d'],
#     u'author': [{u'affiliation': [],
#       u'family': u'Karplus',
#       u'given': u'Martin'}],
#     u'container-title': [u'Nature Chemical Biology', u'Nat Chem Biol'],
#     u'deposited': {u'date-parts': [[2011, 8, 17]],
#      u'timestamp': 1313539200000},
#     u'indexed': {u'date-parts': [[2015, 6, 7]], u'timestamp': 1433684395886},
#     u'issue': u'9',
#     u'issued': {u'date-parts': [[2011, 8, 17]]},
#     u'member': u'http://id.crossref.org/member/339',
#     u'page': u'648-648',
#     u'prefix': u'http://id.crossref.org/prefix/10.1038',
#     u'publisher': u'Nature Publishing Group',
#     u'reference-count': 1,
#     u'score': 2.8144283,
#     u'source': u'CrossRef',
#     u'subject': [u'Molecular Biology', u'Cell Biology'],
#     u'subtitle': [],
#     u'title': [u'Behind the folding funnel diagram'],
#     u'type': u'journal-article',
#     u'volume': u'7'},
#    {u'DOI': u'10.1063/1.1743005',
#     u'ISSN': [u'0021-9606'],
#     u'URL': u'http://dx.doi.org/10.1063/1.1743005',
#     u'author': [{u'affiliation': [],
#       u'family': u'Karplus',
#       u'given': u'Martin'}],
#     u'container-title': [u'The Journal of Chemical Physics',
#      u'J. Chem. Phys.'],
#     u'deposited': {u'date-parts': [[2014, 2, 27]],
#      u'timestamp': 1393459200000},
#     u'indexed': {u'date-parts': [[2015, 6, 9]], u'timestamp': 1433851842094},
#     u'issue': u'3',
#     u'issued': {u'date-parts': [[1956]]},
#     u'member': u'http://id.crossref.org/member/317',
#     u'page': u'605',
#     u'prefix': u'http://id.crossref.org/prefix/10.1063',
#     u'publisher': u'AIP Publishing',
#     u'reference-count': 6,
#     u'score': 2.8144283,
#     u'source': u'CrossRef',
#     u'subject': [u'Physical and Theoretical Chemistry',
#      u'Physics and Astronomy(all)'],
#     u'subtitle': [],
#     u'title': [u'Charge Distribution in the Hydrogen Molecule'],
#     u'type': u'journal-article',
#     u'volume': u'25'},
#    {u'DOI': u'10.1038/scientificamerican0486-42',
#     u'ISSN': [u'0036-8733'],
#     u'URL': u'http://dx.doi.org/10.1038/scientificamerican0486-42',
#     u'alternative-id': [u'scientificamerican0486-42'],
#     u'author': [{u'affiliation': [],
#       u'family': u'Karplus',
#       u'given': u'Martin'},
#      {u'affiliation': [], u'family': u'McCammon', u'given': u'J. Andrew'}],
#     u'container-title': [u'Sci Am', u'Scientific American'],
#     u'deposited': {u'date-parts': [[2011, 7, 15]],
#      u'timestamp': 1310688000000},
#     u'indexed': {u'date-parts': [[2015, 2, 7]], u'timestamp': 1423299501726},
#     u'issue': u'4',
#     u'issued': {u'date-parts': [[1986, 4]]},
#     u'member': u'http://id.crossref.org/member/339',
#     u'page': u'42-51',
#     u'prefix': u'http://id.crossref.org/prefix/10.1038',
#     u'publisher': u'Nature Publishing Group',
#     u'reference-count': 0,
#     u'score': 2.8144283,
#     u'source': u'CrossRef',
#     u'subject': [u'General'],
#     u'subtitle': [],
#     u'title': [u'The Dynamics of Proteins'],
#     u'type': u'journal-article',
#     u'volume': u'254'}],
#   u'items-per-page': 20,
#   u'query': {u'search-terms': u'Martin Karplus', u'start-index': 0},
#   u'total-results': 673374},
#  u'message-type': u'work-list',
#  u'message-version': u'1.0.0',
#  u'status': u'ok'}
